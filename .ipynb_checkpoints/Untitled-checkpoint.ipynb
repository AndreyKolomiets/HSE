# %%
from fbm import FBM
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
for H in np.arange(0.1, 1, 0.2):
    X = FBM(1000, hurst=H, length=1000)
    figure()
    plot(X.fbm())
    title('H='+str(H))
# Out:
# C:\Users\andrey\Anaconda3\lib\site-packages\fbm\fbm.py:155: UserWarning: Combination of increments n and Hurst value H invalid for Davies-Harte method. Reverting to Hosking method. Occurs when n is small and Hurst is close to 1.
#   warnings.warn('Combination of increments n and Hurst value H '
